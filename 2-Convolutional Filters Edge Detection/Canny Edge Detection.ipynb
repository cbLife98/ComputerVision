# %%
# Imports needed 
import numpy as np
import matplotlib.pyplot as plt
import cv2   # Computer vision library

# %matplotlib inline

# %%
# Read the image
image = cv2.imread('images/sunflower.jpg')

# Dimensions of the image 
print("The Dimensions of the image are: ",image.shape)

# Make a copy of the image
image_copy = np.copy(image)

# Change BGR to RGB
image_copy = cv2.cvtColor(image_copy,cv2.COLOR_BGR2RGB)

# Diplay the image
plt.imshow(image_copy)
# Out:
# The Dimensions of the image are:  (1024, 768, 3)

# %%
# Change  RGB to gray
gray = cv2.cvtColor(image_copy,cv2.COLOR_BGR2GRAY)

# Diplay the image
plt.imshow(gray,cmap='gray')

# %%
# Define upper and lower thresholds
lower = 80
upper= 240

edges = cv2.Canny(gray,lower,upper)

plt.imshow(edges,cmap = 'gray')

# %%
# comparing wide and tight

wide = cv2.Canny(gray,30,150)
tight = cv2.Canny(gray,50,80)

f, (ax1,ax2) = plt.subplots(1,2,figsize = (20,10))
ax1.imshow(wide,cmap = 'gray')
ax2.imshow(tight,cmap = 'gray')
