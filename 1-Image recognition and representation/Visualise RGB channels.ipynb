# %%
# Imports needed 
import numpy as np
import matplotlib.pyplot as plt
import cv2   # Computer vision library

# %matplotlib inline

# %%
# Read the image
image = cv2.imread('images/traffic.jpg')

# Dimensions of the image 
print("The Dimensions of the image are: ",image.shape)
# Out:
# The Dimensions of the image are:  (1080, 1000, 3)

# %%
# Visualising RGB channels 

r = image[:,:,0]
g = image[:,:,1]
b = image[:,:,2]

f, (ax1,ax2,ax3) = plt.subplots(1,3,figsize = (10,10))

ax1.set_title("RED")
ax1.imshow(r,cmap ='gray')

ax2.set_title("GREEN")
ax2.imshow(g,cmap ='gray')

ax3.set_title("BLUE")
ax3.imshow(b,cmap ='gray')
